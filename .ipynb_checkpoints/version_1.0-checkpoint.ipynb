# %%
import pandas as pd 
import numpy as np
import math
import operator
from geopy.geocoders import Nominatim
import re

import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import nltk.corpus
from gensim.models import Word2Vec

# %%
df=pd.read_excel (r'/home/deepank/Downloads/GUNA_WORK/Guna_Project/data_new.xlsx') 

pd.options.display.max_colwidth=200

df=df.sort_values(by=['Jobs','Location'])
df=df.dropna(how='any')

key_job={}
for i,j in enumerate(df['Jobs'].unique()):
    key_job[j]=i

key_loc={}
for k in df['Location'].unique():
    geolocator = Nominatim(user_agent="place")
    location = geolocator.geocode(i)
    key_loc[k]=[location.latitude, location.longitude]

    #right now pseudo weights are being used but this will chandge to actual geographical coordinates to calculate distance
df['Location']=df['Location'].map(key_loc)
df['Jobs']=df['Jobs'].map(key_job)
df.head(3)
# Out:
#                                                                                                                                                                                                         Bio  \
# 3                                                                                                                                                                       Engineer | Big Data | ML | Security
# 5   • A technocrat with 6+ Years of experience in Security/Network administration and with technical expertise in the design, implementation, operations and support functions.\n• Hands on exposure on ...
# 8                                                                                                                                                                       Data & network security engineer \n
# 0   Rahul has 12+ years of experience in Cyber Security, IT RISK Consulting, Data Privacy and Managed Security Solutions,Network Security Solutions. Rahul’s experience spans across multiple industries...
# 2   Having a work experience of 5 years in HR Domain .\n In-depth and hands-on experience in managing the entire life cycle from Recruitment.\n Having experience of working with the Top Most IT clie...
# 1   Extensive and in depth understanding of the key business principals and technologies, driving successful and dynamic financial organizations. Successful execution of Greenfield/Brownfield IT-Netwo...
# 7   Experienced System Engineer with a demonstrated history of working in the information technology and services industry. Strong information technology professional skilled in CDH, C++, SAP HANA, Ve...
# 6   I am a goal oriented individual with high work ethics, leadership skills, and positive attitude towards individual and organizational growth.\n\nBusiness Analytics and Consulting have always fasci...
# 28                                                                           Consultancy Services like raising funds from Banks and other Financial Institutions and assisting in making Business Plans. \n
# 32  Post Graduate in Finance from Centre for Management Develpment ( CMD 95-97). Have worked with leading Banks and HFC in Retail Mortgage - Home Loans and Loan against properties having exepence of 1...
#
#                     Location  \
# 3   [33.9204332, -6.3676093]
# 5   [33.9204332, -6.3676093]
# 8   [33.9204332, -6.3676093]
# 0   [33.9204332, -6.3676093]
# 2   [33.9204332, -6.3676093]
# 1   [33.9204332, -6.3676093]
# 7   [33.9204332, -6.3676093]
# 6   [33.9204332, -6.3676093]
# 28  [33.9204332, -6.3676093]
# 32  [33.9204332, -6.3676093]
#
#                                                                                                                                                                                                        Tags  \
# 3   13  for Data Structures13\nProgramming\n8  for Programming8\nAlgorithms\n6  for Algorithms6\nCloud Computing\n1 endorsement for Cloud Computing1\nTools & Technologies\nPython\n14  for Python14\nLi...
# 5   DHCP\n16  for DHCP16\nOSPF\n15  for OSPF15\nFirewalls\n10  for Firewalls10\nDNS\n7  for DNS7\nBGP\n7  for BGP7\nData Center\n6  for Data Center6\nSecurity\n6  for Security6\nRouting\n5  for Routin...
# 8                                                                                                                                                             Security\nInformation Security\nCybersecurity
# 0   162  for Security99\nFirewalls\n172  for Firewalls99\nVPN\n68  for VPN68\nVulnerability Assessment\n64  for Vulnerability Assessment64\nISO 27001\n32  for ISO 2700132\nPenetration Testing\n32  for...
# 2   Recruiting\n37  for Recruiting37\nExecutive Search\n29  for Executive Search29\nTechnical Recruiting\n14  for Technical Recruiting14\nBenefits Negotiation\n13  for Benefits Negotiation13\nSDLC\n12...
# 1                                                                 Firewalls\n6  for Firewalls6\nWAN\n5  for WAN5\nNetwork Security\n4  for Network Security4\nOther Skills \nNetworking\n3  for Networking3
# 7   Machine Learning\nReporting & Analysis\nBig Data\nWeb Analytics\nBusiness Analysis\nBusiness Intelligence\nCloud Computing\nData Analysis\nData Management\nData Modeling\nData Visualization\nStati...
# 6   Industry Knowledge\nAndroid Development\n3  for Android Development3\nData Structures\n3  for Data Structures3\nProgramming\n5  for Programming5\nBusiness Analytics\nReporting & Analysis\n1 endors...
# 28                               Industry Knowledge\nBusiness Analysis\n7  for Business Analysis7\nSales Management\n6  for Sales Management6\nTools & Technologies\nMicrosoft Word\n8  for Microsoft Word8
# 32  Industry Knowledge\nCredit\n43  for Credit43\nStrategy\n20  for Strategy20\nLoans\n19  for Loans19\nRetail Banking\n19  for Retail Banking19\nMortgage Lending\n18  for Mortgage Lending18\nCross Se...
#
#     Jobs
# 3      0
# 5      0
# 8      0
# 0      0
# 2      0
# 1      0
# 7      0
# 6      0
# 28     1
# 32     1

# %%
# WordNet is left to be used as synonymous wording 
# some work on regex here is required.
dt=df.copy()
tokenizer = RegexpTokenizer(r'\w+')

for i,j in enumerate(dt['Tags']):
    tag=[]
    for token in tokenizer.tokenize(j):
        token=re.sub(r'\d+','',token)
        if token not in stopwords.words('english') and len(token)!=0 and token!='&':
            tag.append(token)
    print(i,list(set(tag)))
    dt.iat[i,2]=list(set(tag))    
dt.head()
# Out:
# 0 ['endorsement', 'Computing', 'Algorithms', 'Technologies', 'Cloud', 'NET', 'SQL', 'Python', 'Programming', 'Linux', 'Tools', 'Data', 'Structures']
# 1 ['NAT', 'OSPF', 'Filtering', 'First', 'Open', 'WAN', 'Shortest', 'HSRP', 'VLAN', 'Skills', 'Data', 'Active', 'endorsement', 'STP', 'Juniper', 'IDS', 'RIP', 'BGP', 'Nexus', 'Security', 'Fortinet', 'CCNA', 'Content', 'Center', 'CCNP', 'IPS', 'Networking', 'Network', 'Technologies', 'Routing', 'DHCP', 'URL', 'Failover', 'ER', 'Tools', 'MPLS', 'Servers', 'Checkpoint', 'Path', 'Troubleshooting', 'JNCIA', 'palo', 'Astaro', 'Directory', 'DNS', 'Other', 'Firewalls', 'Cisco', 'Engineering', 'Sonicwall', 'ASA', 'VTP']
# 2 ['Cybersecurity', 'Security', 'Information']
# 3 ['CISSP', 'VPN', 'Assessments', 'Management', 'Computer', 'Forensics', 'Response', 'IP', 'Organizational', 'Intelligence', 'CISM', 'Cyber', 'Digital', 'Risk', 'Cause', 'Skills', 'Penetration', 'Application', 'Assessment', 'Cybersecurity', 'endorsement', 'Services', 'Analysis', 'Technical', 'Security', 'Internal', 'Strategy', 'Threat', 'Operations', 'ISO', 'Audit', 'Audits', 'IPSec', 'TCP', 'Leadership', 'Manager', 'IT', 'IPS', 'Networking', 'Policy', 'Incident', 'Strategic', 'Network', 'Technologies', 'Technology', 'Architecture', 'Team', 'Defense', 'Managed', 'CEH', 'Tools', 'Design', 'Troubleshooting', 'Interpersonal', 'Vulnerability', 'Thought', 'Certified', 'Testing', 'Root', 'CTI', 'Other', 'Firewalls', 'Cisco', 'Infrastructure', 'Reviews', 'Enterprise', 'Information']
# 4 ['Interpersonal', 'Internet', 'Contract', 'Negotiation', 'Recruitment', 'Management', 'Technical', 'Search', 'Talent', 'Resumes', 'Other', 'Acquisition', 'Sourcing', 'Employee', 'Executive', 'SDLC', 'Skills', 'Screening', 'Benefits', 'Recruiting']
# 5 ['Network', 'WAN', 'Security', 'Other', 'Firewalls', 'Skills', 'Networking']
# 6 ['Computing', 'Big', 'Management', 'Visualization', 'Analytics', 'Open', 'MongoDB', 'Intelligence', 'MapReduce', 'Apache', 'SQL', 'Machine', 'Impala', 'Web', 'Skills', 'Statistics', 'Data', 'Matlab', 'endorsement', 'Vertica', 'Analysis', 'HANA', 'Talend', 'Modeling', 'Cassandra', 'Business', 'Office', 'Database', 'Unix', 'Tableau', 'Pig', 'Learning', 'R', 'Technologies', 'Hadoop', 'Databases', 'CDH', 'Cloud', 'Development', 'Windows', 'SAP', 'Tools', 'HTML', 'C', 'Hive', 'Microsoft', 'Cloudera', 'Scala', 'Reporting', 'HPE', 'Studio', 'Other', 'HBase']
# 7 ['Management', 'Visualization', 'PowerPoint', 'Analytics', 'Industry', 'Alteryx', 'Linux', 'Skills', 'Data', 'Structures', 'Project', 'endorsement', 'Analysis', 'Cleaning', 'Knowledge', 'Internal', 'Business', 'Audit', 'Office', 'Android', 'BI', 'Tableau', 'Science', 'Technologies', 'Databases', 'Architecture', 'Development', 'DAX', 'Programming', 'Tools', 'HTML', 'C', 'MySQL', 'Microsoft', 'Excel', 'Reporting', 'Power', 'Mining', 'Other', 'QlikView']
# 8 ['Microsoft', 'Analysis', 'Word', 'Management', 'Sales', 'Knowledge', 'Technologies', 'Industry', 'Business', 'Tools']
# 9 ['Management', 'Negotiation', 'MIS', 'Industry', 'Customer', 'Wealth', 'Organizational', 'Risk', 'Building', 'Cross', 'Skills', 'Retail', 'Banking', 'functional', 'Services', 'Analysis', 'Systems', 'Knowledge', 'Strategy', 'Branch', 'Business', 'Lending', 'Managing', 'Credit', 'Leadership', 'Finance', 'Vendor', 'Relationship', 'Technologies', 'Markets', 'Financial', 'New', 'Development', 'Team', 'Start', 'Tools', 'ups', 'Underwriting', 'Interpersonal', 'CRM', 'Mortgage', 'Cards', 'Other', 'Loans', 'Information', 'Selling']
# 10 ['Finance', 'Banking', 'Interpersonal', 'Analysis', 'Strategic', 'Management', 'Corporate', 'Negotiation', 'Financial', 'Strategy', 'Development', 'Risk', 'Leadership', 'Skills', 'Planning', 'Project']
# 11 ['Valuation', 'Management', 'Analytics', 'Skills', 'Data', 'Project', 'Analysis', 'Modeling', 'Business', 'Market', 'Entry', 'Office', 'Process', 'Technologies', 'Financial', 'Development', 'Team', 'Improvement', 'Tools', 'Interpersonal', 'Microsoft', 'Other']
# 12 ['Structuring', 'Management', 'Program', 'MIS', 'Auditing', 'Risk', 'Income', 'Tax', 'Managerial', 'Project', 'Banking', 'Analysis', 'Systems', 'Modeling', 'Internal', 'Business', 'Credit', 'Planning', 'Due', 'Finance', 'Strategic', 'Technologies', 'Financial', 'Diligence', 'Tools', 'Controls', 'Reporting', 'Accounting', 'Information']
# 13 ['endorsement', 'Interpersonal', 'CRM', 'Management', 'Corporate', 'Performance', 'Report', 'Communications', 'Organizational', 'Talent', 'Team', 'Development', 'Writing', 'Teamwork', 'Leadership', 'Skills', 'Presentations', 'Recruiting']
# 14 ['Microsoft', 'Word', 'PowerPoint', 'Knowledge', 'Technologies', 'Excel', 'Industry', 'Research', 'Tools', 'Office']
# 15 ['Finance', 'endorsement', 'development', 'Analysis', 'cricket', 'Management', 'Corporate', 'Sports', 'Markets', 'Strategy', 'Financial', 'Business', 'Other', 'International', 'business', 'Accounting', 'Skills', 'Project']
# 16 ['Management', 'PowerPoint', 'Customer', 'Skills', 'Project', 'Analysis', 'Strategy', 'Business', 'Leadership', 'Planning', 'Strategic', 'Technologies', 'Self', 'Research', 'Financial', 'Development', 'Team', 'Tools', 'confidence', 'Interpersonal', 'Microsoft', 'Word', 'Other', 'Administration', 'Teamwork', 'Service']
# 17 ['Finance', 'Algorithms', 'Trading']
# 18 ['Management', 'Resources', 'PowerPoint', 'Customer', 'Organizational', 'Skills', 'Project', 'endorsement', 'Business', 'Leadership', 'Planning', 'Finance', 'Workforce', 'Strategic', 'Technologies', 'Financial', 'Development', 'Team', 'Tools', 'Human', 'Interpersonal', 'Other', 'Teamwork', 'Service', 'Resource']
# 19 ['Personnel', 'Resources', 'Management', 'Organizational', 'Talent', 'Skills', 'Banking', 'Strategy', 'Business', 'Finance', 'Vendor', 'Relationship', 'Strategic', 'Performance', 'Development', 'Acquisition', 'Sourcing', 'Human', 'Interpersonal', 'CRM', 'Other', 'Interviews', 'HR', 'Training']
# 20 ['Management', 'Computer', 'MIS', 'Customer', 'Operating', 'Hardware', 'Outlook', 'Skills', 'Recruiting', 'Systems', 'Public', 'Speaking', 'Vendor', 'Relationship', 'English', 'Technologies', 'Performance', 'Databases', 'Team', 'Windows', 'Access', 'Tools', 'HTML', 'Troubleshooting', 'Interpersonal', 'CRM', 'Languages', 'Teamwork', 'Service', 'Information']
# 21 ['PowerPoint', 'Management', 'Industry', 'Customer', 'PLC', 'Auditing', 'SQL', 'Skills', 'endorsement', 'Knowledge', 'Programmable', 'Public', 'Leadership', 'Speaking', 'Technologies', 'Research', 'Windows', 'Logic', 'Tools', 'Time', 'C', 'Interpersonal', 'Microsoft', 'Word', 'Controller', 'Service']
# 22 ['Management', 'PowerPoint', 'Resources', 'Skills', 'Tax', 'endorsement', 'Systems', 'HRIS', 'Corporate', 'Technologies', 'Research', 'Tools', 'Onboarding', 'Human', 'Interpersonal', 'Microsoft', 'Word', 'Excel', 'Teamwork', 'HR', 'Information']
# 23 ['Management', 'Analytics', 'Event', 'Intelligence', 'Web', 'Skills', 'Data', 'Marketing', 'Media', 'Strategy', 'Public', 'Office', 'Speaking', 'PHP', 'English', 'R', 'Technologies', 'JavaScript', 'CSS', 'Social', 'Research', 'Development', 'Windows', 'Python', 'Programming', 'Artificial', 'Tools', 'HTML', 'C', 'Interpersonal', 'Microsoft', 'Photoshop', 'Languages', 'Other', 'Teamwork']
# 24 ['Big', 'Management', 'PowerPoint', 'Analytics', 'OCR', 'Event', 'Customer', 'Intelligence', 'Networks', 'Apache', 'Recommender', 'SQL', 'Machine', 'CNN', 'Spark', 'Skills', 'Statistics', 'Structures', 'Data', 'Matlab', 'endorsement', 'Recognition', 'Analysis', 'Storm', 'Systems', 'RNN', 'Neural', 'Business', 'Character', 'Public', 'Optical', 'Speaking', 'NLP', 'JAVA', 'Convolutional', 'Science', 'Kafka', 'R', 'Technologies', 'Hadoop', 'JavaScript', 'Python', 'Programming', 'Artificial', 'Tools', 'Keras', 'learning', 'HTML', 'C', 'Algorithms', 'Microsoft', 'TensorFlow', 'Word', 'Interpersonal', 'Hive', 'Excel', 'Mining', 'XGBoost', 'Other', 'Service']
# 25 ['Visualization', 'Industry', 'Web', 'Skills', 'Data', 'Structures', 'Deep', 'endorsement', 'Knowledge', 'Style', 'Office', 'Sheets', 'Cascading', 'NumPy', 'Science', 'Learning', 'Technologies', 'CSS', 'Development', 'Scikit', 'Tools', 'HTML', 'C', 'Seaborn', 'Microsoft', 'Matplotlib', 'Learn', 'Pandas', 'Other']
# 26 ['PowerPoint', 'LESS', 'SQL', 'Machine', 'Web', 'Linux', 'Data', 'Structures', 'WebServices', 'Style', 'SolidWorks', 'Office', 'Sheets', 'Android', 'Cascading', 'SASS', 'Agile', 'Learning', 'React', 'Technologies', 'js', 'CSS', 'Development', 'Windows', 'AJAX', 'Applications', 'Python', 'Java', 'Tools', 'RESTful', 'HTML', 'C', 'Algorithms', 'Microsoft', 'MySQL', 'Word', 'Scala', 'Excel', 'D', 'Methodologies']
# 27 ['AWS', 'Open', 'MongoDB', 'SQL', 'jQuery', 'Web', 'Skills', 'endorsement', 'Services', 'Style', 'Virtualization', 'Public', 'Leadership', 'Sheets', 'Cascading', 'Android', 'PHP', 'Amazon', 'Speaking', 'Native', 'React', 'Technologies', 'JavaScript', 'js', 'CSS', 'Jenkins', 'Development', 'Source', 'Python', 'Programming', 'Java', 'Git', 'Tools', 'HTML', 'C', 'MySQL', 'Interpersonal', 'Software']
# 28 ['Management', 'Intelligence', 'Machine', 'Skills', 'Data', 'Structures', 'Project', 'Matlab', 'endorsement', 'Pi', 'Systems', 'Modeling', 'Style', 'Natural', 'Sheets', 'NumPy', 'Cascading', 'Robotics', 'NLP', 'Predictive', 'Learning', 'Technologies', 'JavaScript', 'CSS', 'Arduino', 'Language', 'Processing', 'Photography', 'Python', 'Artificial', 'Tools', 'Raspberry', 'HTML', 'C', 'Algorithms', 'Interpersonal', 'TensorFlow', 'Matplotlib', 'Photoshop', 'Microcontrollers', 'Software', 'Pandas', 'Embedded', 'Other', 'Teamwork', 'Communication', 'Adobe']
# 29 ['Mobile', 'Management', 'SQL', 'jQuery', 'Linux', 'Skills', 'endorsement', 'Core', 'Office', 'Technologies', 'JavaScript', 'Performance', 'CSS', 'Oracle', 'Development', 'Team', 'Python', 'Programming', 'Tools', 'Java', 'HTML', 'C', 'MySQL', 'Microsoft', 'Interpersonal', 'Software', 'Excel', 'Testing', 'Other', 'Eclipse']
# 30 ['Ionic', 'Firebase', 'framework']
# 31 ['C', 'Algorithms', 'Knowledge', 'Industry', 'Java', 'Data', 'Structures']
# 32 ['C', 'Learning', 'namePython', 'numberC', 'CSS', 'CCPP', 'nameCore', 'Course', 'nameHTML', 'Machine', 'Java']
# 33 ['C', 'endorsement', 'Microsoft', 'Pycharm', 'Excel', 'Skills', 'Language', 'Other', 'Programming', 'Office', 'Matlab']
# 34 ['Interpersonal', 'Analysis', 'Learning', 'Management', 'Technologies', 'Civil', 'Deep', 'Language', 'Development', 'Business', 'Other', 'Engineering', 'Python', 'Programming', 'Tools', 'Skills', 'Data', 'Planning', 'Project']
# 35 ['Big', 'Management', 'PowerPoint', 'Analytics', 'Machine', 'Skills', 'Data', 'Matlab', 'Structures', 'Statistics', 'Project', 'Motivational', 'Analysis', 'Style', 'Regression', 'Leadership', 'Sheets', 'Office', 'Cascading', 'Speaking', 'Logistic', 'Technologies', 'CSS', 'Databases', 'Team', 'Programming', 'Motivation', 'Tools', 'HTML', 'learning', 'C', 'Algorithms', 'Microsoft', 'Interpersonal', 'Word', 'Excel', 'Other', 'Teamwork', 'Communication']
# 36 ['Big', 'Industry', 'Apache', 'SQL', 'Linux', 'Spark', 'Skills', 'Data', 'endorsement', 'Knowledge', 'Technologies', 'Technology', 'Development', 'Healthcare', 'Python', 'Programming', 'Java', 'Tools', 'C', 'Algorithms', 'MySQL', 'Software', 'Mining', 'Other', 'Engineering', 'XML', 'Information']
#                                                                                                                                                                                                        Bio  \
# 3                                                                                                                                                                      Engineer | Big Data | ML | Security
# 5  • A technocrat with 6+ Years of experience in Security/Network administration and with technical expertise in the design, implementation, operations and support functions.\n• Hands on exposure on ...
# 8                                                                                                                                                                      Data & network security engineer \n
# 0  Rahul has 12+ years of experience in Cyber Security, IT RISK Consulting, Data Privacy and Managed Security Solutions,Network Security Solutions. Rahul’s experience spans across multiple industries...
# 2  Having a work experience of 5 years in HR Domain .\n In-depth and hands-on experience in managing the entire life cycle from Recruitment.\n Having experience of working with the Top Most IT clie...
#
#                    Location  \
# 3  [33.9204332, -6.3676093]
# 5  [33.9204332, -6.3676093]
# 8  [33.9204332, -6.3676093]
# 0  [33.9204332, -6.3676093]
# 2  [33.9204332, -6.3676093]
#
#                                                                                                                                                                                                       Tags  \
# 3                                                                                 [endorsement, Computing, Algorithms, Technologies, Cloud, NET, SQL, Python, Programming, Linux, Tools, Data, Structures]
# 5  [NAT, OSPF, Filtering, First, Open, WAN, Shortest, HSRP, VLAN, Skills, Data, Active, endorsement, STP, Juniper, IDS, RIP, BGP, Nexus, Security, Fortinet, CCNA, Content, Center, CCNP, IPS, Networki...
# 8                                                                                                                                                                   [Cybersecurity, Security, Information]
# 0  [CISSP, VPN, Assessments, Management, Computer, Forensics, Response, IP, Organizational, Intelligence, CISM, Cyber, Digital, Risk, Cause, Skills, Penetration, Application, Assessment, Cybersecurit...
# 2  [Interpersonal, Internet, Contract, Negotiation, Recruitment, Management, Technical, Search, Talent, Resumes, Other, Acquisition, Sourcing, Employee, Executive, SDLC, Skills, Screening, Benefits, ...
#
#    Jobs
# 3     0
# 5     0
# 8     0
# 0     0
# 2     0

# %%
model = Word2Vec(dt['Tags'], min_count = 1)

# %%
print(model['Internet'])
# Out:
# 37
# [-0.00447809  0.00121786  0.00223617  0.00103133  0.00389633  0.00010707
#   0.00400563 -0.00123123 -0.00240377  0.00381262 -0.00412314  0.00087707
#   0.00050632 -0.00388758  0.00091198  0.00375138 -0.00432232 -0.00493994
#   0.00033647  0.00192707  0.00115959  0.00364595  0.00350562 -0.00278259
#  -0.0048889   0.00207338 -0.0027739  -0.00493413  0.00311167  0.00277733
#  -0.00462559 -0.00225677 -0.00494406 -0.0046475   0.00373682 -0.00295606
#   0.00239585 -0.00179964 -0.00413184 -0.00177557  0.00174666  0.00351982
#   0.00220203 -0.00312949 -0.00201525  0.00045121 -0.00163084 -0.00351086
#   0.00437138 -0.00312947 -0.00497936 -0.00390469  0.00468771  0.00317016
#   0.00261903 -0.00346148  0.00117699 -0.00018235  0.00370373 -0.00159292
#  -0.00242476  0.00479267  0.00098639  0.00475386 -0.00403559 -0.00426376
#  -0.00481865  0.00357989  0.00038626  0.00253426  0.00416298 -0.00348017
#   0.00383769  0.00245486  0.00122204  0.00084716  0.0001065   0.00322959
#  -0.0024148   0.00406811  0.00257845 -0.00033949 -0.00139768  0.00175504
#   0.00386888 -0.00134307  0.00350016 -0.003648   -0.00399072 -0.00098421
#   0.00199689 -0.00058548 -0.00189894  0.00217238 -0.00093108 -0.00062539
#   0.00047529 -0.00247134  0.00012793  0.00256774]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
#portfolio of peron who is searching

#Self_P='HR'
Self_P=3

#Self_Loc='NCR'
Self_Loc=[1,1]

#portfolio of person who is being searched

#P_search='Data Security'
P_search=1
k=2

# %%
data_x=df[df['Jobs']==P_search]
distances=[]
for x in range(len(data_x)):
    dist = euclideanDistance(Self_Loc, data_x.iloc[x,1])
    distances.append([x, dist])
distances.sort(key=operator.itemgetter(1))

for i in range(k):
    print("\nPerson:- "+str(i+1))
    print(data_x.iloc[distances[i][0]])
# Out:
# Person:- 1
# Bio         I am a goal oriented individual with high work ethics, leadership skills, and positive attitude towards individual and organizational growth.\n\nBusiness Analytics and Consulting have always fasci...
# Location                                                                                                                                                                                   [-8.8181292, 13.2464237]
# Tags        Industry Knowledge\nAndroid Development\n3  for Android Development3\nData Structures\n3  for Data Structures3\nProgramming\n5  for Programming5\nBusiness Analytics\nReporting & Analysis\n1 endors...
# Jobs                                                                                                                                                                                                              1
# Name: 6, dtype: object
#
# Person:- 2
# Bio         Extensive and in depth understanding of the key business principals and technologies, driving successful and dynamic financial organizations. Successful execution of Greenfield/Brownfield IT-Netwo...
# Location                                                                                                                                                                                   [18.9387711, 72.8353355]
# Tags                                                                      Firewalls\n6  for Firewalls6\nWAN\n5  for WAN5\nNetwork Security\n4  for Network Security4\nOther Skills \nNetworking\n3  for Networking3
# Jobs                                                                                                                                                                                                              1
# Name: 1, dtype: object
